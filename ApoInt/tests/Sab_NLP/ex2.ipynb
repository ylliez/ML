# %%
# # INST
# !pip3 show spacy
# !pip3 show tracery
# !pip3 install -U spacy
# !pip3 install -U tracery

# %%
# # INIT
import random
import spacy
import spacy.cli
import spacy.displacy
# from spacy import displacy
spacy.cli.download("en_core_web_md")
nlp = spacy.load("en_core_web_md")

# import numpy as np
# import pandas as pd
# import tracery
# from tracery.modifiers import base_english
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 386.6 kB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# spaCy test with cat text

# process text file into string
catText = open("assets/cat.txt").read() 
# print(catText)

# process string into spaCy Doc
catDoc = nlp(catText)
# print(catDoc)
# print(catDoc.text.length)

# #  print all tokens 
# # in catText string, i.e. letters
# for token in catText:
#     print (token)
# len(catText)
# nlp.max_length = len(catText) + 100
# # in catDoc Doc, i.e. words
# for token in catDoc:
#     print (token)
# len(catDoc)
# nlp.max_length = len(catDoc) + 100

# %%
for token in catDoc:
    print(token.text, token.pos_, token.dep_)
# Out:
# The DET det
# cat NOUN nsubj
# Felis PROPN compound
# catus NOUN appos
# is AUX ROOT
# a DET det
# domestic ADJ amod
# species NOUN attr
# of ADP prep
# small ADJ amod
# carnivorous ADJ amod
# mammal NOUN pobj
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# the DET det
# only ADV advmod
# domesticated VERB amod
# species NOUN attr
# in ADP prep
# the DET det
# family NOUN compound
# Felidae PROPN pobj
# and CCONJ cc
# is AUX auxpass
# commonly ADV advmod
# referred VERB conj
# to ADP prep
# as SCONJ mark
# the DET det
# domestic ADJ amod
# cat NOUN nsubj
# or CCONJ cc
# house NOUN compound
# cat NOUN conj
# to PART aux
# distinguish VERB advcl
# it PRON dobj
# from ADP prep
# the DET det
# wild ADJ amod
# members NOUN pobj
# of ADP prep
# the DET det
# family NOUN pobj
# . PUNCT punct
# Cats NOUN nsubjpass
# are AUX auxpass
# commonly ADV advmod
# kept VERB ccomp
# as ADP prep
# house NOUN compound
# pets NOUN pobj
# , PUNCT punct
# but CCONJ cc
# can AUX aux
# also ADV advmod
# ...

# %%
# bibleText = open("assets/bible.txt").read() 
# quranText = open("assets/quran.txt").read() 
# bgitaText = open("assets/bhagavadGita.txt").read() 
# vedasText = open("assets/vedas.txt").read() 
# # nlp.max_length = 5000000
# # bibleDoc = nlp(bibleText)
# # quranDoc = nlp(quranText)
# # bgitaDoc = nlp(bgitaText)
# # vedasDoc = nlp(vedasText)

# %%
# texts = [bibleText,quranText,bgitaText,vedasText]
# for text in texts:
#     print(len(text))

# %%
# quranDoc = nlp(quranText)
# print(len(quranText))
# print(len(quranDoc))

# %%
# bgitaDoc = nlp(bgitaText)
# print(len(bgitaText))
# print(len(bgitaDoc))

# %%
bibleSent1 = "In the beginning God created the heaven and the earth."
quranSent1 = "In the name of Allah, the Beneficent, the Merciful."
bgitaSent1 = "Dhritarashtra said: What did my people and the Pandavas do, O Sangaya, when they assembled together on the holy field of Kurukshetra, desirous to do battle?"
vedasSent1 = "I laud Agni, the chosen Priest, God, minister of sacrifice, the hotar, lavishest of wealth."
bibleSent1Doc = nlp(bibleSent1)
quranSent1Doc = nlp(quranSent1)
bgitaSent1Doc = nlp(bgitaSent1)
vedasSent1Doc = nlp(vedasSent1)

# %%
# spacy.displacy.render(catDoc, style="dep")
spacy.displacy.render(bibleSent1Doc, style="dep")
spacy.displacy.render(quranSent1Doc, style="dep")
spacy.displacy.render(bgitaSent1Doc, style="dep")
spacy.displacy.render(vedasSent1Doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5e7757ddba024b02ae76bc95fcba8119-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...
